# %% [markdown]
# ### Categorical data: split in to "ordinal" and "nominal" data

# %% [markdown]
# ### Nominal data Encoding

# %%
import pandas as pd

# %%
df = pd.DataFrame({"Name":["wscube","cow","cat","dog","black"]})
df
# Out:
#      Name
# 0  wscube
# 1     cow
# 2     cat
# 3     dog
# 4   black

# %%
from sklearn.preprocessing import LabelEncoder

# %%
la = LabelEncoder()   # perform label encodeing 
df["en_name"] = la.fit_transform(df['Name'])

# %%
df
# Out:
#      Name  en_name
# 0  wscube        4
# 1     cow        2
# 2     cat        1
# 3     dog        3
# 4   black        0

# %%
dataset = pd.read_csv("loan.csv")
dataset.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
dataset["Property_Area"].unique()   # unique tell what the data present in it
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
# perform encodeing on "property area"
la = LabelEncoder()
la.fit(dataset["Property_Area"])
# Out:
# LabelEncoder()

# %%
dataset["Property_Area"]=la.transform(dataset["Property_Area"])

# %%
dataset["Property_Area"].unique()   # unique tell what the data present in it
# Out:
# array([2, 0, 1])

# %%
dataset.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History  Property_Area Loan_Status
# 0             1.0              2           Y
# 1             1.0              0           N
# ...

# %% [markdown]
#  ## Ordinal encoding

# %%
# two methoid to perform ordinal encoding first is using sklearn and second is map function
import pandas as pd

# %%
# we create a dataset 
df = pd.DataFrame({"size":["s","m","l","xl","s","m","l","s","s","l","xl","m"]})
df.head(3)
# Out:
#   size
# 0    s
# 1    m
# 2    l

# %%
ord_data = [["s","m","l","xl"]]

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories=ord_data)
oe.fit(df[["size"]])
# Out:
# OrdinalEncoder(categories=[['s', 'm', 'l', 'xl']])

# %%
 df["size_en"]=oe.transform(df[["size"]])

# %%
df
# Out:
#    size  size_en
# 0     s      0.0
# 1     m      1.0
# 2     l      2.0
# 3    xl      3.0
# 4     s      0.0
# 5     m      1.0
# 6     l      2.0
# 7     s      0.0
# 8     s      0.0
# 9     l      2.0
# 10   xl      3.0
# 11    m      1.0

# %% [markdown]
# ### second method to perform ordinal using map function

# %%
# first we create a dictionary 
ord_data1 = {"s":0,"m":1,"l":2,"xl":3}  # these number will chose randomly  any number like 5,6,7,8 or any thing

# %%
df["size_en-map"] =df["size"].map(ord_data1)

# %%
df
# Out:
#    size  size_en  size_en-map
# 0     s      0.0            0
# 1     m      1.0            1
# 2     l      2.0            2
# 3    xl      3.0            3
# 4     s      0.0            0
# 5     m      1.0            1
# 6     l      2.0            2
# 7     s      0.0            0
# 8     s      0.0            0
# 9     l      2.0            2
# 10   xl      3.0            3
# 11    m      1.0            1

# %%
# perdporm ordinal operation on real dataset 
dataset = pd.read_csv("loan.csv")
dataset.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
dataset["Property_Area"].unique()  # to see how many element or category of data
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
en_data_ord = [['Rural','Semiurban','Urban']]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
orn =OrdinalEncoder(categories=en_data_ord)
dataset["Property_Area"]= orn.fit_transform(dataset[["Property_Area"]])

# %%
dataset.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...
